# %%
# Create fake orders to save in db
import numpy as np

# %%
# common statuses from dhl website
status = ['Parcel is out for delivery.',
'Parcel has arrived at station: SG-SINGAPORE-Singapore',
'Parcel has been picked up by courier.',
'Sender is preparing to ship your parcel.',
'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.',
'Departed Facility in DUBAI - UNITED ARAB EMIRATES',
'Departed Facility in LEIPZIG - GERMANY',
'Clearance processing complete at DUBAI UNITED ARAB EMIRATES',
'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC',
'Processed at LEIPZIG - GERMANY',
'Arrived at Sort Facility LEIPZIG - GERMANY',
'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC',
'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)',
'Processed at Sort Facility SINGAPORE - SINGAPORE',
'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'
'']

# %%
order_list = []
for i in range(1,1000):
    pairs = []
    if i < 10:
        pairs.append('Order ID' +'00'+str(i))
        pairs.append(np.random.choice(status))
        order_list.append(pairs)
    elif i < 100:
        pairs.append('Order ID' + '0'+str(i))
        pairs.append(np.random.choice(status))
        order_list.append(pairs)
    else:
        pairs.append('Order ID' +str(i))
        pairs.append(np.random.choice(status))
        order_list.append(pairs)

# %%
order_list
# Out:
# [['Order ID001', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
#  ['Order ID002',
#   'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
#  ['Order ID003', 'Departed Facility in LEIPZIG - GERMANY'],
#  ['Order ID004', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
#  ['Order ID005', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
#  ['Order ID006', 'Parcel is out for delivery.'],
#  ['Order ID007',
#   'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
#  ['Order ID008', 'Parcel is out for delivery.'],
#  ['Order ID009',
#   'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
#  ['Order ID010', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
#  ['Order ID011', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
#  ['Order ID012', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
#  ['Order ID013',
#   'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
# ...

# %%
order_list = [['Order ID001', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID002',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID003', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID004', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID005', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID006', 'Parcel is out for delivery.'],
 ['Order ID007',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID008', 'Parcel is out for delivery.'],
 ['Order ID009',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID010', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID011', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID012', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID013',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID014', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID015',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID016', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID017', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID018', 'Sender is preparing to ship your parcel.'],
 ['Order ID019', 'Sender is preparing to ship your parcel.'],
 ['Order ID020', 'Parcel has been picked up by courier.'],
 ['Order ID021', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID022', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID023',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID024', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID025', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID026', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID027', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID028', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID029', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID030', 'Parcel has been picked up by courier.'],
 ['Order ID031', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID032', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID033',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID034', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID035',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID036', 'Parcel has been picked up by courier.'],
 ['Order ID037', 'Sender is preparing to ship your parcel.'],
 ['Order ID038', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID039',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID040', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID041', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID042',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID043', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID044', 'Parcel has been picked up by courier.'],
 ['Order ID045', 'Sender is preparing to ship your parcel.'],
 ['Order ID046', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID047', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID048', 'Sender is preparing to ship your parcel.'],
 ['Order ID049', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID050', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID051', 'Parcel has been picked up by courier.'],
 ['Order ID052',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID053',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID054', 'Parcel is out for delivery.'],
 ['Order ID055',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID056', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID057', 'Sender is preparing to ship your parcel.'],
 ['Order ID058', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID059', 'Parcel is out for delivery.'],
 ['Order ID060',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID061', 'Parcel has been picked up by courier.'],
 ['Order ID062',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID063',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID064', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID065', 'Sender is preparing to ship your parcel.'],
 ['Order ID066', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID067', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID068',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID069', 'Parcel is out for delivery.'],
 ['Order ID070', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID071', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID072',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID073', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID074', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID075', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID076', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID077', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID078', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID079', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID080', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID081',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID082', 'Sender is preparing to ship your parcel.'],
 ['Order ID083', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID084', 'Parcel has been picked up by courier.'],
 ['Order ID085', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID086',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID087', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID088', 'Sender is preparing to ship your parcel.'],
 ['Order ID089', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID090', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID091', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID092',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID093', 'Parcel has been picked up by courier.'],
 ['Order ID094', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID095', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID096', 'Parcel is out for delivery.'],
 ['Order ID097', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID098', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID099', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID100',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID101', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID102', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID103',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID104',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID105', 'Parcel has been picked up by courier.'],
 ['Order ID106', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID107', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID108',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID109', 'Parcel has been picked up by courier.'],
 ['Order ID110', 'Parcel is out for delivery.'],
 ['Order ID111', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID112', 'Sender is preparing to ship your parcel.'],
 ['Order ID113',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID114',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID115',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID116', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID117', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID118', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID119', 'Parcel is out for delivery.'],
 ['Order ID120', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID121', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID122', 'Sender is preparing to ship your parcel.'],
 ['Order ID123', 'Parcel has been picked up by courier.'],
 ['Order ID124',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID125', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID126', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID127', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID128', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID129',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID130', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID131',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID132', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID133', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID134', 'Sender is preparing to ship your parcel.'],
 ['Order ID135', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID136', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID137', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID138', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID139', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID140', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID141', 'Sender is preparing to ship your parcel.'],
 ['Order ID142', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID143', 'Parcel is out for delivery.'],
 ['Order ID144', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID145', 'Sender is preparing to ship your parcel.'],
 ['Order ID146',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID147', 'Sender is preparing to ship your parcel.'],
 ['Order ID148', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID149',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID150', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID151', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID152', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID153', 'Parcel has been picked up by courier.'],
 ['Order ID154', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID155', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID156', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID157', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID158',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID159', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID160', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID161',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID162', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID163', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID164', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID165', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID166', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID167', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID168', 'Parcel is out for delivery.'],
 ['Order ID169',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID170', 'Parcel has been picked up by courier.'],
 ['Order ID171',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID172', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID173', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID174', 'Sender is preparing to ship your parcel.'],
 ['Order ID175', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID176', 'Parcel has been picked up by courier.'],
 ['Order ID177', 'Sender is preparing to ship your parcel.'],
 ['Order ID178', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID179', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID180', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID181', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID182', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID183', 'Parcel has been picked up by courier.'],
 ['Order ID184', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID185', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID186', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID187', 'Parcel is out for delivery.'],
 ['Order ID188', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID189', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID190', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID191', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID192', 'Sender is preparing to ship your parcel.'],
 ['Order ID193', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID194', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID195', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID196', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID197',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID198', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID199', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID200', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID201', 'Parcel is out for delivery.'],
 ['Order ID202', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID203',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID204', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID205', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID206', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID207',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID208', 'Parcel is out for delivery.'],
 ['Order ID209', 'Parcel has been picked up by courier.'],
 ['Order ID210', 'Parcel has been picked up by courier.'],
 ['Order ID211', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID212', 'Parcel has been picked up by courier.'],
 ['Order ID213',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID214',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID215', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID216', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID217',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID218', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID219',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID220', 'Sender is preparing to ship your parcel.'],
 ['Order ID221',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID222', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID223', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID224', 'Parcel has been picked up by courier.'],
 ['Order ID225', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID226', 'Parcel is out for delivery.'],
 ['Order ID227',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID228', 'Parcel is out for delivery.'],
 ['Order ID229',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID230', 'Parcel has been picked up by courier.'],
 ['Order ID231',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID232', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID233', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID234', 'Parcel is out for delivery.'],
 ['Order ID235', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID236',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID237',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID238', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID239',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID240', 'Sender is preparing to ship your parcel.'],
 ['Order ID241', 'Sender is preparing to ship your parcel.'],
 ['Order ID242', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID243', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID244', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID245',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID246', 'Parcel has been picked up by courier.'],
 ['Order ID247', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID248', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID249', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID250', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID251',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID252', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID253',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID254', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID255', 'Parcel is out for delivery.'],
 ['Order ID256',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID257', 'Parcel is out for delivery.'],
 ['Order ID258', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID259', 'Sender is preparing to ship your parcel.'],
 ['Order ID260',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID261', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID262', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID263', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID264', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID265', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID266', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID267', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID268', 'Parcel is out for delivery.'],
 ['Order ID269', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID270', 'Sender is preparing to ship your parcel.'],
 ['Order ID271', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID272', 'Sender is preparing to ship your parcel.'],
 ['Order ID273', 'Parcel is out for delivery.'],
 ['Order ID274',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID275', 'Parcel is out for delivery.'],
 ['Order ID276',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID277', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID278',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID279', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID280', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID281', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID282', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID283', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID284',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID285', 'Parcel is out for delivery.'],
 ['Order ID286', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID287',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID288', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID289', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID290',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID291', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID292', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID293', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID294', 'Parcel has been picked up by courier.'],
 ['Order ID295', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID296',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID297', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID298', 'Parcel is out for delivery.'],
 ['Order ID299', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID300', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID301', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID302', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID303', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID304', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID305', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID306', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID307', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID308', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID309', 'Sender is preparing to ship your parcel.'],
 ['Order ID310', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID311', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID312', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID313',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID314', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID315', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID316', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID317', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID318', 'Sender is preparing to ship your parcel.'],
 ['Order ID319', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID320', 'Parcel is out for delivery.'],
 ['Order ID321', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID322',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID323', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID324', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID325', 'Sender is preparing to ship your parcel.'],
 ['Order ID326', 'Parcel has been picked up by courier.'],
 ['Order ID327', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID328', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID329', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID330', 'Sender is preparing to ship your parcel.'],
 ['Order ID331', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID332', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID333', 'Parcel is out for delivery.'],
 ['Order ID334', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID335', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID336',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID337',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID338', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID339', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID340', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID341', 'Sender is preparing to ship your parcel.'],
 ['Order ID342', 'Sender is preparing to ship your parcel.'],
 ['Order ID343', 'Sender is preparing to ship your parcel.'],
 ['Order ID344', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID345', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID346', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID347', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID348', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID349', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID350', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID351', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID352', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID353', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID354', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID355', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID356', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID357', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID358', 'Parcel is out for delivery.'],
 ['Order ID359', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID360', 'Parcel has been picked up by courier.'],
 ['Order ID361', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID362', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID363', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID364',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID365', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID366',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID367', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID368',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID369', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID370', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID371',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID372', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID373',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID374', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID375', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID376', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID377', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID378', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID379', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID380', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID381', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID382',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID383', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID384', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID385', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID386', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID387', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID388',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID389', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID390', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID391', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID392', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID393', 'Parcel is out for delivery.'],
 ['Order ID394', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID395', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID396', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID397', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID398',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID399', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID400',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID401', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID402', 'Parcel is out for delivery.'],
 ['Order ID403', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID404', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID405', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID406', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID407', 'Parcel has been picked up by courier.'],
 ['Order ID408', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID409', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID410',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID411', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID412', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID413',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID414',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID415', 'Parcel has been picked up by courier.'],
 ['Order ID416', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID417', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID418',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID419', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID420', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID421', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID422', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID423', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID424', 'Parcel has been picked up by courier.'],
 ['Order ID425', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID426',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID427', 'Parcel has been picked up by courier.'],
 ['Order ID428', 'Parcel is out for delivery.'],
 ['Order ID429', 'Parcel has been picked up by courier.'],
 ['Order ID430',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID431', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID432', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID433', 'Sender is preparing to ship your parcel.'],
 ['Order ID434', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID435', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID436', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID437',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID438', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID439', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID440',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID441',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID442', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID443', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID444', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID445', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID446', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID447',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID448',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID449', 'Parcel is out for delivery.'],
 ['Order ID450', 'Sender is preparing to ship your parcel.'],
 ['Order ID451', 'Parcel is out for delivery.'],
 ['Order ID452', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID453', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID454',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID455', 'Sender is preparing to ship your parcel.'],
 ['Order ID456',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID457', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID458', 'Sender is preparing to ship your parcel.'],
 ['Order ID459', 'Sender is preparing to ship your parcel.'],
 ['Order ID460',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID461', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID462',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID463', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID464',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID465',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID466', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID467', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID468', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID469', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID470', 'Parcel is out for delivery.'],
 ['Order ID471',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID472',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID473',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID474', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID475', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID476', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID477', 'Sender is preparing to ship your parcel.'],
 ['Order ID478',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID479', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID480', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID481',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID482', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID483', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID484', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID485',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID486',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID487', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID488', 'Parcel has been picked up by courier.'],
 ['Order ID489', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID490', 'Sender is preparing to ship your parcel.'],
 ['Order ID491', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID492', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID493', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID494', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID495', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID496', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID497', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID498', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID499', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID500',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID501', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID502', 'Sender is preparing to ship your parcel.'],
 ['Order ID503', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID504', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID505', 'Parcel is out for delivery.'],
 ['Order ID506', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID507', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID508', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID509', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID510',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID511', 'Parcel has been picked up by courier.'],
 ['Order ID512', 'Parcel has been picked up by courier.'],
 ['Order ID513', 'Parcel is out for delivery.'],
 ['Order ID514', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID515', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID516', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID517', 'Sender is preparing to ship your parcel.'],
 ['Order ID518',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID519',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID520', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID521',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID522', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID523', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID524', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID525', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID526',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID527', 'Parcel is out for delivery.'],
 ['Order ID528', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID529', 'Parcel is out for delivery.'],
 ['Order ID530', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID531', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID532', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID533', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID534', 'Parcel is out for delivery.'],
 ['Order ID535', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID536', 'Parcel is out for delivery.'],
 ['Order ID537', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID538', 'Parcel has been picked up by courier.'],
 ['Order ID539', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID540', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID541',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID542', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID543', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID544', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID545', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID546', 'Parcel is out for delivery.'],
 ['Order ID547', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID548',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID549', 'Parcel has been picked up by courier.'],
 ['Order ID550', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID551', 'Sender is preparing to ship your parcel.'],
 ['Order ID552', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID553', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID554', 'Sender is preparing to ship your parcel.'],
 ['Order ID555', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID556', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID557', 'Parcel is out for delivery.'],
 ['Order ID558',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID559', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID560',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID561',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID562', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID563', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID564', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID565', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID566',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID567', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID568',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID569', 'Parcel has been picked up by courier.'],
 ['Order ID570', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID571', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID572', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID573', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID574', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID575', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID576', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID577', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID578',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID579', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID580', 'Sender is preparing to ship your parcel.'],
 ['Order ID581', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID582', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID583', 'Parcel has been picked up by courier.'],
 ['Order ID584',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID585', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID586',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID587', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID588', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID589',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID590', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID591',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID592', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID593',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID594', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID595', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID596', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID597', 'Sender is preparing to ship your parcel.'],
 ['Order ID598', 'Parcel is out for delivery.'],
 ['Order ID599', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID600',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID601', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID602', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID603', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID604', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID605', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID606', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID607', 'Parcel is out for delivery.'],
 ['Order ID608', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID609', 'Parcel has been picked up by courier.'],
 ['Order ID610', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID611',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID612', 'Parcel is out for delivery.'],
 ['Order ID613', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID614', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID615', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID616', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID617', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID618', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID619', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID620', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID621', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID622', 'Parcel has been picked up by courier.'],
 ['Order ID623', 'Parcel is out for delivery.'],
 ['Order ID624',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID625',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID626',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID627', 'Sender is preparing to ship your parcel.'],
 ['Order ID628', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID629',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID630', 'Sender is preparing to ship your parcel.'],
 ['Order ID631', 'Parcel has been picked up by courier.'],
 ['Order ID632', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID633', 'Sender is preparing to ship your parcel.'],
 ['Order ID634', 'Parcel has been picked up by courier.'],
 ['Order ID635',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID636', 'Sender is preparing to ship your parcel.'],
 ['Order ID637', 'Sender is preparing to ship your parcel.'],
 ['Order ID638', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID639', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID640', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID641',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID642', 'Parcel is out for delivery.'],
 ['Order ID643', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID644',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID645', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID646', 'Parcel has been picked up by courier.'],
 ['Order ID647',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID648', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID649',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID650', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID651', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID652', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID653', 'Sender is preparing to ship your parcel.'],
 ['Order ID654', 'Parcel is out for delivery.'],
 ['Order ID655', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID656', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID657', 'Parcel is out for delivery.'],
 ['Order ID658', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID659', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID660', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID661',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID662', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID663',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID664', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID665',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID666', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID667', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID668', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID669', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID670', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID671',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID672',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID673', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID674', 'Sender is preparing to ship your parcel.'],
 ['Order ID675', 'Parcel has been picked up by courier.'],
 ['Order ID676', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID677', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID678',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID679',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID680', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID681', 'Sender is preparing to ship your parcel.'],
 ['Order ID682', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID683', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID684', 'Parcel is out for delivery.'],
 ['Order ID685', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID686', 'Sender is preparing to ship your parcel.'],
 ['Order ID687',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID688', 'Parcel has been picked up by courier.'],
 ['Order ID689', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID690', 'Parcel is out for delivery.'],
 ['Order ID691',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID692',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID693', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID694', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID695', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID696', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID697', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID698', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID699', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID700', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID701',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID702', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID703', 'Parcel has been picked up by courier.'],
 ['Order ID704', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID705', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID706', 'Parcel is out for delivery.'],
 ['Order ID707', 'Sender is preparing to ship your parcel.'],
 ['Order ID708', 'Parcel is out for delivery.'],
 ['Order ID709', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID710',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID711', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID712', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID713', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID714',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID715', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID716',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID717', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID718', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID719', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID720', 'Parcel is out for delivery.'],
 ['Order ID721', 'Sender is preparing to ship your parcel.'],
 ['Order ID722', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID723', 'Sender is preparing to ship your parcel.'],
 ['Order ID724',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID725', 'Parcel has been picked up by courier.'],
 ['Order ID726', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID727',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID728', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID729', 'Parcel has been picked up by courier.'],
 ['Order ID730', 'Parcel has been picked up by courier.'],
 ['Order ID731', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID732', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID733', 'Parcel has been picked up by courier.'],
 ['Order ID734', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID735', 'Sender is preparing to ship your parcel.'],
 ['Order ID736', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID737', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID738', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID739', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID740', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID741',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID742',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID743', 'Sender is preparing to ship your parcel.'],
 ['Order ID744', 'Sender is preparing to ship your parcel.'],
 ['Order ID745', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID746', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID747', 'Parcel is out for delivery.'],
 ['Order ID748', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID749', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID750', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID751', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID752',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID753', 'Sender is preparing to ship your parcel.'],
 ['Order ID754', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID755', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID756', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID757', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID758', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID759', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID760', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID761', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID762', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID763',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID764', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID765', 'Parcel is out for delivery.'],
 ['Order ID766',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID767', 'Parcel is out for delivery.'],
 ['Order ID768', 'Sender is preparing to ship your parcel.'],
 ['Order ID769', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID770', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID771',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID772', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID773', 'Sender is preparing to ship your parcel.'],
 ['Order ID774',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID775', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID776', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID777',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID778', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID779', 'Parcel is out for delivery.'],
 ['Order ID780', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID781', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID782', 'Parcel has been picked up by courier.'],
 ['Order ID783', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID784', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID785',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID786', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID787', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID788', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID789', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID790', 'Parcel is out for delivery.'],
 ['Order ID791', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID792', 'Sender is preparing to ship your parcel.'],
 ['Order ID793', 'Parcel is out for delivery.'],
 ['Order ID794', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID795', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID796', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID797',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID798', 'Parcel is out for delivery.'],
 ['Order ID799', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID800', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID801', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID802',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID803', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID804', 'Sender is preparing to ship your parcel.'],
 ['Order ID805', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID806', 'Parcel has been picked up by courier.'],
 ['Order ID807',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID808',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID809', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID810', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID811',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID812',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID813', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID814', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID815', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID816', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID817', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID818', 'Sender is preparing to ship your parcel.'],
 ['Order ID819', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID820', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID821',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID822', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID823', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID824', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID825', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID826', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID827', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID828', 'Parcel is out for delivery.'],
 ['Order ID829', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID830', 'Parcel has been picked up by courier.'],
 ['Order ID831', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID832',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID833', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID834', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID835', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID836', 'Parcel has been picked up by courier.'],
 ['Order ID837', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID838', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID839', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID840',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID841', 'Parcel has been picked up by courier.'],
 ['Order ID842', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID843', 'Parcel has been picked up by courier.'],
 ['Order ID844', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID845', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID846', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID847', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID848', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID849', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID850', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID851',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID852', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID853', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID854', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID855', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID856', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID857', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID858', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID859', 'Sender is preparing to ship your parcel.'],
 ['Order ID860', 'Sender is preparing to ship your parcel.'],
 ['Order ID861', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID862', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID863', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID864', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID865',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID866', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID867', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID868', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID869',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID870',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID871', 'Parcel is out for delivery.'],
 ['Order ID872',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID873', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID874', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID875', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID876',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID877',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID878', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID879', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID880', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID881', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID882', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID883', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID884', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID885', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID886',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID887', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID888', 'Parcel is out for delivery.'],
 ['Order ID889', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID890', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID891',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID892',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID893', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID894', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID895', 'Parcel has been picked up by courier.'],
 ['Order ID896',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID897', 'Parcel has been picked up by courier.'],
 ['Order ID898',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID899',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID900', 'Parcel is out for delivery.'],
 ['Order ID901', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID902', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID903', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID904', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID905', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID906', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID907',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID908', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID909', 'Sender is preparing to ship your parcel.'],
 ['Order ID910', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID911', 'Parcel is out for delivery.'],
 ['Order ID912', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID913', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID914', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID915',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID916', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID917', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID918', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID919', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID920', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID921', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID922', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID923', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID924', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID925',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID926',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID927',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID928', 'Arrived at Sort Facility LEIPZIG - GERMANY'],
 ['Order ID929', 'Parcel is out for delivery.'],
 ['Order ID930', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID931',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID932', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID933',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID934', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID935', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID936', 'Sender is preparing to ship your parcel.'],
 ['Order ID937',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID938', 'Parcel is out for delivery.'],
 ['Order ID939', 'Parcel is out for delivery.'],
 ['Order ID940', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID941', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID942', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID943',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID944', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID945', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID946', 'Sender is preparing to ship your parcel.'],
 ['Order ID947', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID948', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID949',
  'Arrived at Sort Facility LSHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID950', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID951', 'Sender is preparing to ship your parcel.'],
 ['Order ID952', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID953', 'Sender is preparing to ship your parcel.'],
 ['Order ID954', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID955', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID956', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID957', 'Parcel is out for delivery.'],
 ['Order ID958', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID959', 'Sender is preparing to ship your parcel.'],
 ['Order ID960', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID961', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID962', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID963', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID964', 'Parcel is out for delivery.'],
 ['Order ID965', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID966',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID967', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID968', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID969', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID970', 'Parcel has been picked up by courier.'],
 ['Order ID971',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID972', 'Processed at Sort Facility SINGAPORE - SINGAPORE'],
 ['Order ID973', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID974',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID975', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID976', 'Parcel is out for delivery.'],
 ['Order ID977', 'Departed Facility in LEIPZIG - GERMANY'],
 ['Order ID978',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID979', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID980', 'Departed Facility in SHENZHEN - CHINA, PEOPLES REPUBLIC.'],
 ['Order ID981', 'Processed at LEIPZIG - GERMANY'],
 ['Order ID982',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID983', 'Arrived at Delivery Facility in SINGAPORE - SINGAPORE'],
 ['Order ID984',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID985', 'Parcel has been picked up by courier.'],
 ['Order ID986',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID987',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID988', 'Sender is preparing to ship your parcel.'],
 ['Order ID989', 'Departed Facility in DUBAI - UNITED ARAB EMIRATES'],
 ['Order ID990',
  'Arrived at Sort Facility INCHEON OUTSKIRT OF SEOUL - KOREA, REPUBLIC OF (SOUTH KOREA)'],
 ['Order ID991', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID992', 'Processed at SHENZHEN - CHINA, PEOPLES REPUBLIC'],
 ['Order ID993', 'Parcel has been picked up by courier.'],
 ['Order ID994', 'Parcel is out for delivery.'],
 ['Order ID995',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID996', 'Parcel has arrived at station: SG-SINGAPORE-Singapore'],
 ['Order ID997', 'Parcel has been picked up by courier.'],
 ['Order ID998',
  'Clearance processing complete at DUBAI UNITED ARAB EMIRATES'],
 ['Order ID999', 'Processed at Sort Facility SINGAPORE - SINGAPORE']]

# %%
#create yaml file to train chatbot with fake orders
import yaml

with open('../data/orders.yaml', 'w') as f:
    
    data = yaml.dump(order_list, f)
